# %%
##### Starting a new project on data analysis on kaggle #####

# %%
import kaggle
# !kaggle datasets download ankitbansal06/retail-orders
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# retail-orders.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
with zipfile.ZipFile("retail-orders.zip") as zip_ref:
   zip_ref.extractall("retail-orders")

# %%
import os
os.listdir("retail-orders")
# Out:
# ['orders.csv']

# %%
import pandas as pd
data =pd.read_csv ("retail-orders/orders.csv",na_values=["Not Available","unknown"])
data["Ship Mode"].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
data
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
data.columns=data.columns.str.replace(" ","_")

# %%
data
# Out:
#       Order_Id  Order_Date       Ship_Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# ...

# %%
data.head(5)
# Out:
#    Order_Id  Order_Date       Ship_Mode    Segment        Country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               City       State  Postal_Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub_Category       Product_Id  cost_price  List_Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
data["discount"]=(data["List_Price"]*data["Discount_Percent"])*0.01

# %%
data["discount"]
# Out:
# 0        5.2
# 1       21.9
# 2        0.5
# 3       19.2
# 4        1.0
#         ...
# 9989     1.2
# 9990     3.6
# 9991     5.2
# 9992     0.9
# 9993     7.2
# Name: discount, Length: 9994, dtype: float64

# %%
data["Sell_price"]=data["List_Price"]-data["discount"]

# %%
data[["Sell_price"]]
# Out:
#       Sell_price
# 0          254.8
# 1          708.1
# 2            9.5
# 3          940.8
# 4           19.0
# ...          ...
# 9989        28.8
# 9990        86.4
# 9991       254.8
# 9992        29.1
# 9993       232.8
#
# [9994 rows x 1 columns]

# %%
data
# Out:
#       Order_Id  Order_Date       Ship_Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# ...

# %%
data["profit"]=data["Sell_price"]-data["cost_price"]
data["profit"]
# Out:
# 0        14.8
# 1       108.1
# 2        -0.5
# 3       160.8
# 4        -1.0
#         ...
# 9989     -1.2
# 9990     16.4
# 9991     34.8
# 9992     -0.9
# 9993     22.8
# Name: profit, Length: 9994, dtype: float64

# %%
data.dtypes
# Out:
# Order_Id              int64
# Order_Date           object
# Ship_Mode            object
# Segment              object
# Country              object
# City                 object
# State                object
# Postal_Code           int64
# Region               object
# Category             object
# Sub_Category         object
# Product_Id           object
# cost_price            int64
# List_Price            int64
# Quantity              int64
# Discount_Percent      int64
# discount            float64
# Sell_price          float64
# profit              float64
# dtype: object

# %%
data["Order_Date"] = pd.to_datetime(data["Order_Date"].str.strip(), errors="coerce")

# %%
data[["Order_Date"]]
# Out:
#      Order_Date
# 0    2023-03-01
# 1    2023-08-15
# 2    2023-01-10
# 3    2022-06-18
# 4    2022-07-13
# ...         ...
# 9989 2023-02-18
# 9990 2023-03-17
# 9991 2022-08-07
# 9992 2022-11-19
# 9993 2022-07-17
#
# [9994 rows x 1 columns]

# %%
data.columns
# Out:
# Index(['Order_Id', 'Order_Date', 'Ship_Mode', 'Segment', 'Country', 'City',
#        'State', 'Postal_Code', 'Region', 'Category', 'Sub_Category',
#        'Product_Id', 'cost_price', 'List_Price', 'Quantity',
#        'Discount_Percent', 'discount', 'Sell_price', 'profit'],
#       dtype='object')

# %%
data.drop(columns=["List_Price","cost_price","Discount_Percent"],inplace=True)

# %%
from sqlalchemy import create_engine
import pandas as pd
import pymysql  

data = pd.read_csv("retail-orders/orders.csv")  

engine = create_engine("mysql+pymysql://root:Mainak%4045@localhost/vscode")

data.to_sql(name="orders", con=engine, index=False, if_exists="replace")

print("Data inserted successfully!")
# Out:
# Data inserted successfully!

# %%
# Out:
# 6
